# %%
from glob import glob
glob("C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias/*.fits")
# Useful for opening up FITS files
# Out:
# ['C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0001.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0002.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0003.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0004.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0005.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0006.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0007.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0008.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0009.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0010.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0011.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0012.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0013.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0014.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0015.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0016.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0017.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0018.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0019.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0020.fits',
#  'C:/Users/nowar/Downloads/data_2019/data_2019/NNSer/bias\\B120308_0021.fits']

# %%
series, plateNumber, plateNumber_string = 'x', '5267', '05267'  
url = "http://dasch.rc.fas.harvard.edu/extractimage.php?filetype=FITS&series="+str(series)+"&plateNumber="+str(plateNumber)+"&mosaicNumber=0&ra=83.861809&dec=-69.269699&system=J2000&radius=0.083333&scaleFactor=0.986700"
filename = "C:/Users/nowar/Downloads/Demonstration/"+str(series)+"/"+str(series)+plateNumber_string+"_00_01_extract.fit"

import os.path # Checks if a file is already present/exists (ie- in a specified location)
os.path.exists(filename)
# Out:
# False

# %%
import urllib.request # Download [named] files from [named] urls
urllib.request.urlretrieve(url,filename)
# Out:
# ('C:/Users/nowar/Downloads/Demonstration/x/x05267_00_01_extract.fit',
#  <http.client.HTTPMessage at 0x278de141df0>)

# %%
os.path.exists(filename)
# Out:
# True

# %%
from astropy.io import fits
import numpy as np
from matplotlib import pyplot as plt

image = fits.open(filename)
plt.imshow(image[0].data, cmap='gray_r');
